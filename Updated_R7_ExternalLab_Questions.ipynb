# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
import tensorflow as tf

# %% [markdown]
# tf.__version__

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
import tensorflow.keras.datasets.fashion_mnist as fashion_mnist

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
y_train_enc = tf.convert_to_tensor(tf.keras.utils.to_categorical(y_train, num_classes=10))
y_test_enc = tf.convert_to_tensor(tf.keras.utils.to_categorical(y_test, num_classes=10))

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
x_train_norm = x_train / 255.0
x_test_norm = x_test / 255.0

# %%
x_train_reshaped = tf.keras.backend.expand_dims(x_train_norm)
x_test_reshaped = tf.keras.backend.expand_dims(x_test_norm)

# %%
# Initialize model, reshape & normalize data
model = tf.keras.models.Sequential()

#Add first convolutional layer
model.add(tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation='relu'))

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
#Add first convolutional layer
model.add(tf.keras.layers.Conv2D(200, kernel_size=(3,3), activation='relu'))

#Add second convolutional layer
model.add(tf.keras.layers.Conv2D(100, kernel_size=(3,3), activation='relu'))

#Add dropout layer
model.add(tf.keras.layers.Dropout(0.25))

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
#Flatten the output
model.add(tf.keras.layers.Flatten())

#Add output layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
#Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#Fit the  model with the given dataset
model.fit(x_train_reshaped, y_train_enc, validation_data=(x_test_reshaped, y_test_enc), epochs=10, batch_size=32)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 959s 16ms/sample - loss: 0.3756 - accuracy: 0.8653 - val_loss: 0.2879 - val_accuracy: 0.8979
# Epoch 2/10
# 60000/60000 [==============================] - 939s 16ms/sample - loss: 0.2454 - accuracy: 0.9119 - val_loss: 0.2486 - val_accuracy: 0.9108
# Epoch 3/10
# 60000/60000 [==============================] - 937s 16ms/sample - loss: 0.1975 - accuracy: 0.9277 - val_loss: 0.2548 - val_accuracy: 0.9122
# Epoch 4/10
# 60000/60000 [==============================] - 934s 16ms/sample - loss: 0.1617 - accuracy: 0.9412 - val_loss: 0.2511 - val_accuracy: 0.9147
# Epoch 5/10
# 60000/60000 [==============================] - 930s 16ms/sample - loss: 0.1303 - accuracy: 0.9516 - val_loss: 0.2577 - val_accuracy: 0.9201
# Epoch 6/10
# 60000/60000 [==============================] - 933s 16ms/sample - loss: 0.1049 - accuracy: 0.9621 - val_loss: 0.2822 - val_accuracy: 0.9134
# Epoch 7/10
# 60000/60000 [==============================] - 940s 16ms/sample - loss: 0.0879 - accuracy: 0.9675 - val_loss: 0.2979 - val_accuracy: 0.9163
# Epoch 8/10
# 60000/60000 [==============================] - 931s 16ms/sample - loss: 0.0749 - accuracy: 0.9726 - val_loss: 0.3250 - val_accuracy: 0.9123
# Epoch 9/10
# 60000/60000 [==============================] - 931s 16ms/sample - loss: 0.0634 - accuracy: 0.9772 - val_loss: 0.3493 - val_accuracy: 0.9185
# Epoch 10/10
# 60000/60000 [==============================] - 931s 16ms/sample - loss: 0.0601 - accuracy: 0.9777 - val_loss: 0.3690 - val_accuracy: 0.9122

# %%
model.evaluate(x_test_reshaped, y_test_enc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.36903049965053797, 0.9122]
